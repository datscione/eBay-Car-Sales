# %% [markdown]
# In this project we will clean and analyze data on 50,000 used cars listed in eBay Kleinanzeigen.

# %%
import pandas as pd
import numpy as np

autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# There is data on 50,000 autos. Some indices that are missing values are: vehicle type, gearbox, model, fuel type, and not repaired damage.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos_c = autos.copy()

# %%
autos_c
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos_c.rename(columns={"yearOfRegistration":"registration_year", "monthOfRegistration":"registration_month",
                        "notRepairedDamage":"unrepaired_damage", "dateCreated":"ad_created"}, inplace=True)

# %%
def clean_column(col):
    res = [col[0].lower()]
    for chr in col[1:]:
        if chr in ('ABCDEFGHIJKLMNOPQRSTUVWXYZ'):
            res.append('_')
            res.append(chr.lower())
        else:
            res.append(chr)
    return ''.join(res)

new_col = []
for c in autos_c.columns:
    cleaned_auto_c = clean_column(c)
    new_col.append(cleaned_auto_c)
autos_c.columns = new_col
print(autos_c.columns)
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_p_s', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos_c.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_p_s   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# We made the column titles lower case and snakecase. This makes the date easier to analyze and read.

# %%
autos_c.describe()
# Out:
#        registration_year     power_p_s  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# nrofpictures has mostly 0s. The postal code, powerps, registration year (min of 1000 and max of 9999 do not make sense) column needs more investigation. Odometer reading (#km) and price (#$) are numerical data stored as text.

# %%
autos_c["price"] = autos_c["price"].str.replace("$","").str.replace(",","").astype(int)
autos_c["odometer"] = autos_c["odometer"].str.replace("km","").str.replace(",","").astype(int)

autos_c.rename({"price":"price_USD", "odometer":"odometer_km"}, axis=1, inplace=True)

autos_c
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
odometer = autos_c["odometer_km"]
odometer.unique().shape
# Out:
# (13,)

# %% [markdown]
# There are 13 unique values for the odometer readings.

# %%
odometer.describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# The values for 50%, 75%, and max are all 150000. This is suspicious and will need to be explored further. The minimum reading for a car listing was 5000. If the mean was 125732, this means most of the cars had high odometer readings, closer to 150000 than 100000.

# %%
odometer.value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %% [markdown]
# As expected 150000 was the highest odometer reading. Because the counts at 150000 are so much more than other readings, this forces the lower values to have less significance. There are no obvious outliers. Let's look at null values to explore the odometer readings further.

# %%
print(odometer.value_counts(dropna=False))
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %% [markdown]
# We can see above that there are no null odometer values. Now let us explore the auto prices.

# %%
price = autos_c["price_USD"] 
price.unique().shape
# Out:
# (2357,)

# %% [markdown]
# There are 2357 unique prices for the autos.

# %%
price.describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price_USD, dtype: float64

# %% [markdown]
# The minimum price was 0 and the maximum was 100 million. 100 million is too high and 0 is getting a car for free.

# %%
price.value_counts().sort_index(ascending=False).head(10)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# Name: price_USD, dtype: int64

# %% [markdown]
# We saw that the describe() method rounded the car price (99999999) to 100 million. We will remove the 100 million auto price, as this is too high a price for a car and 0, as this is getting a car for free.

# %%
autos_c = autos_c[autos_c["price_USD"].between(1,27322222)]

# %%
autos_c.describe()
# Out:
#           price_USD  registration_year     power_p_s    odometer_km  \
# count  4.857800e+04       48578.000000  48578.000000   48578.000000
# mean   8.069542e+03        2004.753119    117.209869  125765.675820
# std    1.800356e+05          88.632571    200.652070   39793.193823
# min    1.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.200000e+03        1999.000000     71.000000  125000.000000
# 50%    3.000000e+03        2004.000000    107.000000  150000.000000
# 75%    7.490000e+03        2008.000000    150.000000  150000.000000
# max    2.732222e+07        9999.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        48578.000000         48578.0  48578.000000
# mean             5.781794             0.0  50976.081230
# std              3.685768             0.0  25749.448131
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30657.000000
# ...

# %% [markdown]
# We know have a minimum price of 1 and a maximum of 27 million.

# %% [markdown]
# Now we'll analyze the date columns.

# %%
print(autos_c[['date_crawled', 'ad_created', 'last_seen']][0:5])
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
# 19       2016-03-17
# 20       2016-03-05
# 21       2016-03-06
# 22       2016-03-28
# 23       2016-03-10
# 24       2016-04-03
# 25       2016-03-21
# 26       2016-04-03
# 28       2016-03-19
# 29       2016-04-02
# 30       2016-03-14
#             ...
# 49968    2016-04-01
# 49969    2016-03-17
# 49970    2016-03-21
# 49971    2016-03-29
# 49972    2016-03-26
# 49973    2016-03-27
# 49975    2016-03-27
# 49976    2016-03-19
# 49977    2016-03-31
# 49978    2016-04-04
# 49979    2016-03-20
# 49980    2016-03-12
# 49981    2016-03-15
# 49982    2016-03-29
# ...

# %% [markdown]
# The percent distrribution for the dates the ads were created is shown below.

# %%
print(autos_c['ad_created'].value_counts(normalize=True, dropna=False))
# Out:
# 2016-04-03 00:00:00    0.038845
# 2016-03-20 00:00:00    0.037939
# 2016-03-21 00:00:00    0.037610
# 2016-04-04 00:00:00    0.036889
# 2016-03-12 00:00:00    0.036766
# 2016-03-14 00:00:00    0.035181
# 2016-04-02 00:00:00    0.035139
# 2016-03-28 00:00:00    0.034975
# 2016-03-07 00:00:00    0.034728
# 2016-03-29 00:00:00    0.034069
# 2016-03-15 00:00:00    0.034007
# 2016-04-01 00:00:00    0.033678
# 2016-03-19 00:00:00    0.033678
# 2016-03-30 00:00:00    0.033493
# 2016-03-08 00:00:00    0.033348
# 2016-03-09 00:00:00    0.033163
# 2016-03-11 00:00:00    0.032896
# 2016-03-22 00:00:00    0.032813
# 2016-03-26 00:00:00    0.032257
# 2016-03-23 00:00:00    0.032052
# 2016-03-10 00:00:00    0.031887
# 2016-03-31 00:00:00    0.031887
# 2016-03-25 00:00:00    0.031743
# 2016-03-17 00:00:00    0.031290
# 2016-03-27 00:00:00    0.030981
# 2016-03-16 00:00:00    0.030117
# 2016-03-24 00:00:00    0.029273
# 2016-03-05 00:00:00    0.022891
# 2016-03-13 00:00:00    0.017004
# ...

# %% [markdown]
# Looking at the ad created dates in ascending order we get.

# %%
print(autos_c['ad_created'].value_counts(normalize=True, dropna=False).sort_index(ascending=True))
# Out:
# 2015-06-11 00:00:00    0.000021
# 2015-08-10 00:00:00    0.000021
# 2015-09-09 00:00:00    0.000021
# 2015-11-10 00:00:00    0.000021
# 2015-12-05 00:00:00    0.000021
# 2015-12-30 00:00:00    0.000021
# 2016-01-03 00:00:00    0.000021
# 2016-01-07 00:00:00    0.000021
# 2016-01-10 00:00:00    0.000041
# 2016-01-13 00:00:00    0.000021
# 2016-01-14 00:00:00    0.000021
# 2016-01-16 00:00:00    0.000021
# 2016-01-22 00:00:00    0.000021
# 2016-01-27 00:00:00    0.000062
# 2016-01-29 00:00:00    0.000021
# 2016-02-01 00:00:00    0.000021
# 2016-02-02 00:00:00    0.000041
# 2016-02-05 00:00:00    0.000041
# 2016-02-07 00:00:00    0.000021
# 2016-02-08 00:00:00    0.000021
# 2016-02-09 00:00:00    0.000021
# 2016-02-11 00:00:00    0.000021
# 2016-02-12 00:00:00    0.000041
# 2016-02-14 00:00:00    0.000041
# 2016-02-16 00:00:00    0.000021
# 2016-02-17 00:00:00    0.000021
# 2016-02-18 00:00:00    0.000041
# 2016-02-19 00:00:00    0.000062
# 2016-02-20 00:00:00    0.000041
# ...

# %% [markdown]
# The ads were created between 06/11/2015 and 04/07/2016. Now let us seen when they were last seen by the crawler.

# %%
print(autos_c['last_seen'].str[:10])
# Out:
# 0        2016-04-06
# 1        2016-04-06
# 2        2016-04-06
# 3        2016-03-15
# 4        2016-04-01
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The median registration year was 2004. The minimum was 1000 (before cars were invented!)  and the maximum year was 9999 (in the future!). Clearly the registration year data needs cleaning. Also, of the 50,000 autos analyzed, we have registration years for 48578 autos, meaning some values are missing.

# %%
autos_c["registration_year"].value_counts().sort_index(ascending=True)
# Out:
# 1000       1
# 1001       1
# 1111       1
# 1800       2
# 1910       5
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       3
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       4
# 1959       6
# 1960      24
# 1961       6
# 1962       4
# 1963       8
# 1964      12
#         ...
# 2000    3156
# 2001    2637
# 2002    2486
# 2003    2699
# 2004    2703
# 2005    2936
# 2006    2671
# 2007    2277
# 2008    2215
# 2009    2086
# 2010    1589
# 2011    1623
# 2012    1310
# 2013     803
# 2014     664
# 2015     392
# 2016    1220
# 2017    1393
# 2018     471
# 2019       2
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       4
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       3
# Name: registration_year, Length: 95, dtype: int64

# %% [markdown]
# The earliest logical registration year listed is 1910. Our data was only collected up to 2016 so we will use this as the maximum year.

# %%
autos_c = autos_c[autos_c["registration_year"].between(1910,2016)]

# %%
autos_c.describe()
# Out:
#           price_USD  registration_year     power_p_s    odometer_km  \
# count  4.669200e+04       46692.000000  46692.000000   46692.000000
# mean   7.717820e+03        2002.908250    117.906943  125581.255890
# std    1.649244e+05           7.190078    184.934094   39857.756314
# min    1.000000e+00        1910.000000      0.000000    5000.000000
# 25%    1.250000e+03        1999.000000     75.000000  100000.000000
# 50%    3.100000e+03        2003.000000    109.000000  150000.000000
# 75%    7.500000e+03        2008.000000    150.000000  150000.000000
# max    2.732222e+07        2016.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        46692.000000         46692.0  46692.000000
# mean             5.826758             0.0  51097.568770
# std              3.670470             0.0  25757.115964
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30827.000000
# ...

# %% [markdown]
# The statistics for the registration year now show a minimum year of 1910 and a maximum of 2016. The average registration year is 2002 and the median is 2003. Now let's look at the perecentage distribution.

# %%
print(autos_c["registration_year"].value_counts(normalize= True).sort_index(ascending=True))
# Out:
# 1910    0.000107
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000043
# 1937    0.000086
# 1938    0.000021
# 1939    0.000021
# 1941    0.000043
# 1943    0.000021
# 1948    0.000021
# 1950    0.000064
# 1951    0.000043
# 1952    0.000021
# 1953    0.000021
# 1954    0.000043
# 1955    0.000043
# 1956    0.000086
# 1957    0.000043
# 1958    0.000086
# 1959    0.000129
# 1960    0.000514
# 1961    0.000129
# 1962    0.000086
# 1963    0.000171
# 1964    0.000257
# 1965    0.000364
# 1966    0.000471
# 1967    0.000557
# 1968    0.000557
#           ...
# 1987    0.001542
# 1988    0.002891
# 1989    0.003727
# 1990    0.007432
# 1991    0.007260
# 1992    0.007946
# 1993    0.009102
# 1994    0.013471
# 1995    0.026300
# 1996    0.029405
# 1997    0.041784
# 1998    0.050608
# 1999    0.062066
# 2000    0.067592
# 2001    0.056476
# 2002    0.053243
# 2003    0.057804
# 2004    0.057890
# 2005    0.062880
# 2006    0.057205
# 2007    0.048766
# ...

# %% [markdown]
# Because in general the registration has increased over time and in 1987 it was only 0.0015%; we can assume that registrations before 1987 were minimal and can be ignored.Let us look at our registration year data again removing these years.

# %%
autos_c = autos_c[autos_c["registration_year"].between(1987,2016)]

# %%
autos_c.describe()
# Out:
#           price_USD  registration_year     power_p_s    odometer_km  \
# count  4.577200e+04       45772.000000  45772.000000   45772.000000
# mean   7.164805e+03        2003.461461    118.521913  126146.006292
# std    1.510737e+05           5.909554    186.268102   39368.238902
# min    1.000000e+00        1987.000000      0.000000    5000.000000
# 25%    1.200000e+03        1999.000000     75.000000  125000.000000
# 50%    3.000000e+03        2003.000000    109.000000  150000.000000
# 75%    7.499000e+03        2008.000000    150.000000  150000.000000
# max    2.732222e+07        2016.000000  17700.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count        45772.000000         45772.0  45772.000000
# mean             5.852246             0.0  51093.637639
# std              3.670115             0.0  25740.071395
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30851.000000
# ...

# %% [markdown]
# The minimum registration year is now 1987 and the maximum is 2016, while the mean is 2003.

# %%
print(autos_c["vehicle_type"].value_counts())
# Out:
# limousine     12315
# kleinwagen    10517
# kombi          8903
# bus            3985
# cabrio         2881
# coupe          2289
# suv            1921
# andere          361
# Name: vehicle_type, dtype: int64

# %%
print(autos_c["brand"].value_counts())
# Out:
# volkswagen        9682
# bmw               5090
# opel              4948
# mercedes_benz     4329
# audi              4022
# ford              3194
# renault           2191
# peugeot           1392
# fiat              1166
# seat               852
# skoda              761
# nissan             710
# mazda              707
# smart              661
# citroen            644
# toyota             586
# hyundai            468
# volvo              409
# mini               407
# mitsubishi         383
# honda              361
# sonstige_autos     335
# kia                330
# alfa_romeo         293
# suzuki             276
# porsche            256
# chevrolet          237
# chrysler           161
# dacia              123
# daihatsu           116
# jeep               103
# subaru             100
# land_rover          94
# saab                76
# daewoo              70
# jaguar              70
# rover               62
# lancia              49
# trabant             35
# lada                23
# ...

# %% [markdown]
# Let us determine brands that represent more than 5% of the vehicles.

# %%
brands = autos_c["brand"].value_counts(normalize=True) # assigns
#the brand percentage value counts to variable named brands
top_brands = brands[brands>0.05].index #assigns brands with >5%
#value counts to variable named top_brands
print(top_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %% [markdown]
# Now we will determine the mean price of each of these top 5% vehicles.

# %%
brand_mean_price = {}

for brand in top_brands:
    selected_brand = autos_c[autos_c["brand"] == brand]
    price_mean = selected_brand['price_USD'].mean()
    brand_mean_price[brand] = int(price_mean)
print(brand_mean_price)
# Out:
# {'bmw': 8577, 'volkswagen': 6516, 'mercedes_benz': 8495, 'ford': 3751, 'audi': 9363, 'opel': 5447}

# %%
brand_mean_price = {}
brand_mean_mileage = {}

for brand in top_brands:
    selected_brand = autos_c[autos_c["brand"] == brand]
    price_mean = selected_brand['price_USD'].mean()
    mileage_mean = selected_brand['odometer_km'].mean()
    brand_mean_price[brand] = int(price_mean)
    brand_mean_mileage[brand] = int(mileage_mean)
    bmp_series = pd.Series(brand_mean_price)
    bmm_series = pd.Series(brand_mean_mileage)
    df = pd.DataFrame(bmp_series, columns=["Mean_Price"])
    df.insert(1, "Mean_Mileage", bmm_series)
print("Brand Mean Price", brand_mean_price)  
print("Brand Mean Mileage", brand_mean_mileage)
print("Brand Mean Price Series Constructor", bmp_series)
print("Brand Mean Mileage Series Constructor", bmm_series)
print(df)
# Out:
# Brand Mean Price {'bmw': 8577, 'volkswagen': 6516, 'mercedes_benz': 8495, 'ford': 3751, 'audi': 9363, 'opel': 5447}
# Brand Mean Mileage {'bmw': 132743, 'volkswagen': 129153, 'mercedes_benz': 131068, 'ford': 125283, 'audi': 129126, 'opel': 129832}
# Brand Mean Price Series Constructor audi             9363
# bmw              8577
# ford             3751
# mercedes_benz    8495
# opel             5447
# volkswagen       6516
# dtype: int64
# Brand Mean Mileage Series Constructor audi             129126
# bmw              132743
# ford             125283
# mercedes_benz    131068
# opel             129832
# volkswagen       129153
# dtype: int64
#                Mean_Price  Mean_Mileage
# audi                 9363        129126
# bmw                  8577        132743
# ford                 3751        125283
# mercedes_benz        8495        131068
# opel                 5447        129832
# volkswagen           6516        129153

# %% [markdown]
# The mileage for all the vehicles were similar, approximately 130,000km. The car prices ranged from 3751 USD for a Ford to 9363 USD for an Audi. The price for an Audi was nearly 2.5 times that of a Ford.
